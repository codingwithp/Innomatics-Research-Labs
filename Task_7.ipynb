# %% [markdown]
# <a href="https://colab.research.google.com/github/codingwithp/Innomatics-Research-Labs/blob/main/Task_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class SmartLight:
    def __init__(self, name):
        self.name=name
        self.status="OFF"
    def turn_on(self):
        self.status="ON"
    def turn_off(self):
        self.status="OFF"
    def display_status(self):
        print(f"{self.name} is {self.status}")

light_name=input("Light Name: ")
action=input("Action (ON/OFF): ")
light=SmartLight(light_name)
if action.upper()=="ON":
    light.turn_on()
else:
    light.turn_off()
light.display_status()
# Out:
# Light Name: ON
# Action (ON/OFF): ON
# ON is ON

# %%
class Employee:
    def __init__(self, name, emp_id, dept):
        self.name=name
        self.emp_id=emp_id
        self.dept=dept
    def display_id_card(self):
        print("Employee ID Card")
        print(f"Name: {self.name}")
        print(f"ID: {self.emp_id}")
        print(f"Department: {self.dept}")

name=input("Employee Name: ")
emp_id=input("Employee ID: ")
dept=input("Department: ")
employee=Employee(name, emp_id, dept)
employee.display_id_card()

# %%
class Contact:
    def __init__(self, name, phone):
        self.name=name
        self.phone=phone
    def display_contact(self):
        print("Contact Saved")
        print(f"Name: {self.name}")
        print(f"Phone: {self.phone}")

name=input("Contact Name: ")
phone=input("Phone Number: ")
contact=Contact(name, phone)
contact.display_contact()
# Out:
# Contact Name: Pragathi
# Phone Number: 9611918068
# Contact Saved
# Name: Pragathi
# Phone: 9611918068

# %%
class Product:
    def __init__(self, name, price):
        self.name=name
        self.price=price
    def display_price_tag(self):
        print(f"Product: {self.name}")
        print(f"Price: ₹{self.price}")

name=input("Product Name: ")
price=input("Price: ")
product=Product(name, price)
product.display_price_tag()
# Out:
# Product Name: ij
# Price: 90
# Product: ij
# Price: ₹90

# %%
class Movie:
    def __init__(self, name, rating):
        self.name=name
        self.rating=rating
    def display_details(self):
        print(f"Movie: {self.name}")
        print(f"Rating: {self.rating} / 5")

name=input("Movie Name: ")
rating=input("Rating: ")
movie=Movie(name, rating)
movie.display_details()
# Out:
# Movie Name: nf,lmw.d
# Rating: 9
# Movie: nf,lmw.d
# Rating: 9 / 5

# %%
class Delivery:
    def __init__(self, customer, address):
        self.customer=customer
        self.address=address
    def display_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer}")
        print(f"Address: {self.address}")

name=input("Customer Name: ")
address=input("Address: ")
delivery=Delivery(name, address)
delivery.display_details()
# Out:
# Customer Name: nadlkqne
# Address: ddq
# Delivery Details
# Customer: nadlkqne
# Address: ddq
