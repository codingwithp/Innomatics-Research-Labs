# %% [markdown]
# <a href="https://colab.research.google.com/github/codingwithp/Innomatics-Research-Labs/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence=input("Enter sentence: ")
words=sentence.split()
unique_words=set(words)
print("Unique words count:",len(unique_words))
print("Unique words:",unique_words)
# Out:
# Enter sentence: hii im so done
# Unique words count: 4
# Unique words: {'done', 'im', 'so', 'hii'}

# %%
employees = { "Ravi": 75000, "Anita": 68000,"Kiran": 72000
}
highest_employee=max(employees, key=employees.get)
print("Highest Salary:", highest_employee, "-",employees[highest_employee])
# Out:
# Highest Salary: Ravi - 75000

# %%
numbers=[45, 22, 89, 10, 66]
maxi=numbers[0]
mini=numbers[0]
for num in numbers:
    if num>maxi:
        maxi=num
    if num<mini:
        mini=num
print("List:",numbers)
print("Max:",maxi)
print("Min:",mini)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
prices = [450, 1200, 899, 1500, 300]
count=0
for price in prices:
    if price>1000:
        count += 1
print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %%
attendance=["P", "P", "A", "P", "P"]
present_days=attendance.count("P")
percentage=(present_days / len(attendance)) * 100
print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %%
phone_numbers=[9876543210, 9123456789, 9876543210]
unique_numbers=set(phone_numbers)
print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %%
text="python"
frequency={}
for char in text:
    frequency[char] = frequency.get(char, 0) + 1
print(frequency)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
numbers=[10, 20, 30]
result=tuple(numbers)
print("Tuple:", result)
# Out:
# Tuple: (10, 20, 30)

# %%
employees={"Ravi": 75000, "Anita": 68000}
key="Ravi"
if key in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %%
marks=[70, 75, 80, 65]
average=sum(marks)/len(marks)
print("Average Marks:", average)
